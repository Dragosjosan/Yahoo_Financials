# %%
import json

all_data = json.load(open('Yahoo_Financials.json'))

for company in all_data:
    print("{}".format(all_data[company]['Valuation Measures']['Trailing P/E']))


[all_data[company]['Valuation Measures']['Trailing P/E'] for company in all_data]
# Out:
# 27.59
# 41.1
# 59.97
# 46.11
# 22.38
# 21.59
# 25.92
# 29.84
# 29.32
# 12.03
# 32.57
# 58.69
# 79.76
# 54.67
# 591.07
# [27.59,
#  41.1,
#  59.97,
#  46.11,
#  22.38,
#  21.59,
#  25.92,
#  29.84,
#  29.32,
#  12.03,
#  32.57,
#  58.69,
#  79.76,
#  54.67,
#  591.07]

# %%
import pandas as pd

df = pd.read_json('Yahoo_Financials.json')

#for idx, company in enumerate(df):
    #print("{}".format(df[company]['Valuation Measures']['Trailing P/E']))

[df[company]['Valuation Measures'] for company in df]
# Out:
# [{'Market Cap (intraday)': 2049999999999.9998,
#   'Enterprise Value': 2109999999999.9998,
#   'Trailing P/E': 27.59,
#   'Forward P/E': 22.99,
#   'PEG Ratio (5 yr expected)': 1.45,
#   'Price/Sales': 6.3,
#   'Price/Book': 29.61,
#   'Enterprise Value/Revenue': 6.49,
#   'Enterprise Value/EBITDA': 21.17},
#  {'Market Cap (intraday)': 225660000000.0,
#   'Enterprise Value': 231660000000.0,
#   'Trailing P/E': 41.1,
#   'Forward P/E': 34.51,
#   'PEG Ratio (5 yr expected)': 2.48,
#   'Price/Sales': 16.49,
#   'Price/Book': 16.69,
#   'Enterprise Value/Revenue': 16.93,
#   'Enterprise Value/EBITDA': 43.44},
#  {'Market Cap (intraday)': 1590000000000.0,
#   'Enterprise Value': 1650000000000.0,
#   'Trailing P/E': 59.97,
#   'Forward P/E': 43.73,
#   'PEG Ratio (5 yr expected)': 1.5899999999999999,
#   'Price/Sales': 3.79,
#   'Price/Book': 15.38,
#   'Enterprise Value/Revenue': 3.95,
#   'Enterprise Value/EBITDA': 28.93},
#  {'Market Cap (intraday)': 254780000000.0,
#   'Enterprise Value': 249940000000.0,
#   'Trailing P/E': 46.11,
#   'Forward P/E': 35.24,
#   'PEG Ratio (5 yr expected)': 1.54,
#   'Price/Sales': 16.02,
#   'Price/Book': 18.34,
#   'Enterprise Value/Revenue': 15.72,
#   'Enterprise Value/EBITDA': 44.76},
#  {'Market Cap (intraday)': 260130000000.0,
#   'Enterprise Value': 360160000000.0,
#   'Trailing P/E': 22.38,
#   'Forward P/E': 15.43,
#   'PEG Ratio (5 yr expected)': 1.04,
#   'Price/Sales': 2.5,
#   'Price/Book': 2.81,
#   'Enterprise Value/Revenue': 3.46,
#   'Enterprise Value/EBITDA': 11.66},
#  {'Market Cap (intraday)': 217840000000.0,
#   'Enterprise Value': 208070000000.0,
#   'Trailing P/E': 21.59,
#   'Forward P/E': 15.09,
#   'PEG Ratio (5 yr expected)': 2.8200000000000003,
#   'Price/Sales': 4.54,
#   'Price/Book': 5.57,
#   'Enterprise Value/Revenue': 4.33,
#   'Enterprise Value/EBITDA': 13.66},
#  {'Market Cap (intraday)': 857870000000.0,
#   'Enterprise Value': 805790000000.0,
#   'Trailing P/E': 25.92,
#   'Forward P/E': 19.92,
#   'PEG Ratio (5 yr expected)': 0.97,
#   'Price/Sales': 9.09,
#   'Price/Book': 6.43,
#   'Enterprise Value/Revenue': 8.54,
#   'Enterprise Value/EBITDA': 17.75},
#  {'Market Cap (intraday)': 1490000000000.0,
#   'Enterprise Value': 1390000000000.0,
#   'Trailing P/E': 29.84,
#   'Forward P/E': 23.64,
#   'PEG Ratio (5 yr expected)': 1.27,
#   'Price/Sales': 7.5600000000000005,
#   'Price/Book': 6.53,
#   'Enterprise Value/Revenue': 7.09,
#   'Enterprise Value/EBITDA': 22.12},
#  {'Market Cap (intraday)': 1490000000000.0,
#   'Enterprise Value': 1370000000000.0,
#   'Trailing P/E': 29.32,
#   'Forward P/E': 23.21,
#   'PEG Ratio (5 yr expected)': 1.25,
#   'Price/Sales': 7.5600000000000005,
#   'Price/Book': 6.42,
#   'Enterprise Value/Revenue': 6.95,
#   'Enterprise Value/EBITDA': 21.71},
#  {'Market Cap (intraday)': 216520000000.0,
#   'Enterprise Value': 235740000000.0,
#   'Trailing P/E': 12.03,
#   'Forward P/E': 11.68,
#   'PEG Ratio (5 yr expected)': 2.34,
#   'Price/Sales': 2.79,
#   'Price/Book': 2.71,
#   'Enterprise Value/Revenue': 3.03,
#   'Enterprise Value/EBITDA': 6.8},
#  {'Market Cap (intraday)': 1800000000000.0,
#   'Enterprise Value': 1760000000000.0,
#   'Trailing P/E': 32.57,
#   'Forward P/E': 28.62,
#   'PEG Ratio (5 yr expected)': 2.01,
#   'Price/Sales': 11.25,
#   'Price/Book': 13.39,
#   'Enterprise Value/Revenue': 10.98,
#   'Enterprise Value/EBITDA': 23.24},
#  {'Market Cap (intraday)': 215040000000.0,
#   'Enterprise Value': 224370000000.0,
#   'Trailing P/E': 58.69,
#   'Forward P/E': 37.39,
#   'PEG Ratio (5 yr expected)': 1.09,
#   'Price/Sales': 8.15,
#   'Price/Book': 16.69,
#   'Enterprise Value/Revenue': 8.5,
#   'Enterprise Value/EBITDA': 39.29},
#  {'Market Cap (intraday)': 342520000000.0,
#   'Enterprise Value': 337370000000.0,
#   'Trailing P/E': 79.76,
#   'Forward P/E': 35.81,
#   'PEG Ratio (5 yr expected)': 2.05,
#   'Price/Sales': 20.54,
#   'Price/Book': 20.2,
#   'Enterprise Value/Revenue': 20.23,
#   'Enterprise Value/EBITDA': 57.98},
#  {'Market Cap (intraday)': 281830000000.0,
#   'Enterprise Value': 278460000000.0,
#   'Trailing P/E': 54.67,
#   'Forward P/E': 41.01,
#   'PEG Ratio (5 yr expected)': 2.46,
#   'Price/Sales': 12.32,
#   'Price/Book': 14.49,
#   'Enterprise Value/Revenue': 12.18,
#   'Enterprise Value/EBITDA': 56.26},
#  {'Market Cap (intraday)': 568260000000.0,
#   'Enterprise Value': 565080000000.0,
#   'Trailing P/E': 591.07,
#   'Forward P/E': 94.38,
#   'PEG Ratio (5 yr expected)': 3.66,
#   'Price/Sales': 15.81,
#   'Price/Book': 24.68,
#   'Enterprise Value/Revenue': 15.72,
#   'Enterprise Value/EBITDA': 124.17}]
